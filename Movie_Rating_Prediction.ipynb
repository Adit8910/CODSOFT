# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
movie_df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/movies.dat', sep='::', encoding='latin-1',header=None, names=['movie_id', 'movie_title', 'genres'])
movie_df.dropna(inplace=True)
movie_df.head()
# Out:
# <ipython-input-13-dd2b04d53d8f>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   movie_df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/movies.dat', sep='::', encoding='latin-1',header=None, names=['movie_id', 'movie_title', 'genres'])
#    movie_id                         movie_title                        genres
# 0         1                    Toy Story (1995)   Animation|Children's|Comedy
# 1         2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2         3             Grumpier Old Men (1995)                Comedy|Romance
# 3         4            Waiting to Exhale (1995)                  Comedy|Drama
# 4         5  Father of the Bride Part II (1995)                        Comedy

# %%
movie_df.shape
# Out:
# (3883, 3)

# %%
movie_df.describe()
# Out:
#           movie_id
# count  3883.000000
# mean   1986.049446
# std    1146.778349
# min       1.000000
# 25%     982.500000
# 50%    2010.000000
# 75%    2980.500000
# max    3952.000000

# %%
movie_df.isna().sum()
# Out:
# movie_id       0
# movie_title    0
# genres         0
# dtype: int64

# %%
ratings=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/ratings.dat", sep="::", engine="python")
ratings.dropna(inplace=True)
ratings.head(10)
# Out:
#    1  1193  5  978300760
# 0  1   661  3  978302109
# 1  1   914  3  978301968
# 2  1  3408  4  978300275
# 3  1  2355  5  978824291
# 4  1  1197  3  978302268
# 5  1  1287  5  978302039
# 6  1  2804  5  978300719
# 7  1   594  4  978302268
# 8  1   919  4  978301368
# 9  1   595  5  978824268

# %%
ratings.describe()
# Out:
#                   1          1193             5     978300760
# count  1.000208e+06  1.000208e+06  1.000208e+06  1.000208e+06
# mean   3.024515e+03  1.865541e+03  3.581563e+00  9.722437e+08
# std    1.728411e+03  1.096041e+03  1.117102e+00  1.215256e+07
# min    1.000000e+00  1.000000e+00  1.000000e+00  9.567039e+08
# 25%    1.506000e+03  1.030000e+03  3.000000e+00  9.653026e+08
# 50%    3.070000e+03  1.835000e+03  4.000000e+00  9.730180e+08
# 75%    4.476000e+03  2.770000e+03  4.000000e+00  9.752209e+08
# max    6.040000e+03  3.952000e+03  5.000000e+00  1.046455e+09

# %%
ratings.shape
# Out:
# (1000208, 4)

# %%
ratings.isna().sum()
# Out:
# 1            0
# 1193         0
# 5            0
# 978300760    0
# dtype: int64

# %%
users=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/users.dat", sep="::", engine="python")
users.dropna(inplace=True)
users.head(10)
# Out:
#     1  F  1.1  10  48067
# 0   2  M   56  16  70072
# 1   3  M   25  15  55117
# 2   4  M   45   7  02460
# 3   5  M   25  20  55455
# 4   6  F   50   9  55117
# 5   7  M   35   1  06810
# 6   8  M   25  12  11413
# 7   9  M   25  17  61614
# 8  10  F   35   1  95370
# 9  11  F   25   1  04093
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_6571686291248932484 = autoviz.get_df('df_6571686291248932484')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# ...

# %%
users.describe()
# Out:
#                  1          1.1           10
# count  6039.000000  6039.000000  6039.000000
# mean   3021.000000    30.644146     8.146547
# std    1743.453469    12.891387     6.329991
# min       2.000000     1.000000     0.000000
# 25%    1511.500000    25.000000     3.000000
# 50%    3021.000000    25.000000     7.000000
# 75%    4530.500000    35.000000    14.000000
# max    6040.000000    56.000000    20.000000

# %%
users.shape
# Out:
# (6039, 5)

# %%
users.isna().sum()
# Out:
# 1        0
# F        0
# 1.1      0
# 10       0
# 48067    0
# dtype: int64

# %%
data=pd.concat([movie_df,ratings,users],axis=1)
data.dropna()
data.head(10)
# Out:
#    movie_id                         movie_title                        genres  \
# 0       1.0                    Toy Story (1995)   Animation|Children's|Comedy
# 1       2.0                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2       3.0             Grumpier Old Men (1995)                Comedy|Romance
# 3       4.0            Waiting to Exhale (1995)                  Comedy|Drama
# 4       5.0  Father of the Bride Part II (1995)                        Comedy
# 5       6.0                         Heat (1995)         Action|Crime|Thriller
# 6       7.0                      Sabrina (1995)                Comedy|Romance
# 7       8.0                 Tom and Huck (1995)          Adventure|Children's
# 8       9.0                 Sudden Death (1995)                        Action
# 9      10.0                    GoldenEye (1995)     Action|Adventure|Thriller
#
#    1  1193  5  978300760     1  F   1.1    10  48067
# 0  1   661  3  978302109   2.0  M  56.0  16.0  70072
# ...

# %%
data.shape
# Out:
# (1000208, 12)

# %%
df=data.drop(["10","48067","978300760"],axis=1)
df.head()
# Out:
#    movie_id                         movie_title                        genres  \
# 0       1.0                    Toy Story (1995)   Animation|Children's|Comedy
# 1       2.0                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2       3.0             Grumpier Old Men (1995)                Comedy|Romance
# 3       4.0            Waiting to Exhale (1995)                  Comedy|Drama
# 4       5.0  Father of the Bride Part II (1995)                        Comedy
#
#    1  1193  5    1  F   1.1
# 0  1   661  3  2.0  M  56.0
# 1  1   914  3  3.0  M  25.0
# 2  1  3408  4  4.0  M  45.0
# 3  1  2355  5  5.0  M  25.0
# 4  1  1197  3  6.0  F  50.0

# %%
df.describe()
# Out:
#           movie_id             1          1193             5            1  \
# count  3883.000000  1.000208e+06  1.000208e+06  1.000208e+06  6039.000000
# mean   1986.049446  3.024515e+03  1.865541e+03  3.581563e+00  3021.000000
# std    1146.778349  1.728411e+03  1.096041e+03  1.117102e+00  1743.453469
# min       1.000000  1.000000e+00  1.000000e+00  1.000000e+00     2.000000
# 25%     982.500000  1.506000e+03  1.030000e+03  3.000000e+00  1511.500000
# 50%    2010.000000  3.070000e+03  1.835000e+03  4.000000e+00  3021.000000
# 75%    2980.500000  4.476000e+03  2.770000e+03  4.000000e+00  4530.500000
# max    3952.000000  6.040000e+03  3.952000e+03  5.000000e+00  6040.000000
#
#                1.1
# count  6039.000000
# mean     30.644146
# std      12.891387
# min       1.000000
# 25%      25.000000
# 50%      25.000000
# 75%      35.000000
# max      56.000000

# %%
df.isna().sum()
# Out:
# movie_id       996325
# movie_title    996325
# genres         996325
# 1                   0
# 1193                0
# 5                   0
# 1              994169
# F              994169
# 1.1            994169
# dtype: int64

# %%
df_final=df.dropna()

# %%
df_final.shape
# Out:
# (3883, 9)

# %%
df_final['1193'].value_counts().plot(kind='bar')
plt.show()

# %%
df_final['movie_id'].plot.hist(bins=25)
plt.xlabel("movie_title")
plt.ylabel("genres")
# Out:
# Text(0, 0.5, 'genres')
